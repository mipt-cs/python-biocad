# %% [markdown]
# # Тест 12
#
# <font color=red>Время выполнения: 60 мин</font>
#
# # <font color=blue>Задача 1. Вычитатель</font>
#
# Напишите функцию `subtract_from_dict()`, вычитающую из значений словаря `D` значения именованных аргументов.
#
# 1. Ключами словаря `D` являются строки, а значениями - натуральные числа.
#
# - Функция `subtract_from_dict()` принимает на вход аргумент `D` без значения по умолчанию и произвольное число именованных аргументов.
#
# - Если среди именованных аргументов есть ключ `'k'` словаря `D`, то из соответствующего значения `D` вычитается значение аргумента `k`.
#
#   1) Если значение элемента с ключом `'k'` в словаре `D` больше значения имнованного аргумента `k`, то новым значением элемента с ключом `'k'` становится разность `D['k'] - k`.
#
#   2) Если `D['k'] <= k`, то из словаря `D` удаляется элемент с ключом `'k'`.
#
# - Пусть на вход функции поступил именованный аргумент `k1` и в словаре `D` нет ключа `'k1'`. В таком случае аргумент функции `k1` никак не влияет на словарь `D`.
#
# - Функция `subtract_from_dict()` ничего не возвращает.
#
# | <font size=3>Словарь `D`<br>до вызова<br>`subtract_from_dict()`</font> | <font size=3>Значения<br>аргументов<br>функции</font> | <font size=3>Вызов<br>функции</font> | <font size=3>Словарь `D`<br>после вызова<br>`subtract_from_dict()`</font> | <font size=3>Комментарий</font> |
# | :---: | :---: | :---: | :---: | :---: |
# | <font size=3>{'a': 1, 'b': 2}</font> | <font size=3>b = 1</font> | <font size=3>f(D, b=b)</font> | <font size=3>{'a': 1, 'b': 1}</font> |<font size=3>Аргумент `b` меньше `D['b']`,<br>и поэтому<br>`D['b'] = D['b'] - b`</font>|
# | <font size=3>{'a': 1, 'b': 2}</font> | <font size=3>b = 2</font> | <font size=3>f(D, b=b)</font> | <font size=3>{'a': 1}</font> |<font size=3>Аргумент `b` равен `D['b']`,<br>и поэтому `D['b']` удаляется</font>|
# | <font size=3>{'a': 1, 'b': 2}</font> | <font size=3>b = 3</font> | <font size=3>f(D, b=b)</font> | <font size=3>{'a': 1}</font> |<font size=3>Аргумент `b` больше `D['b']`,<br>и поэтому `D['b']` удаляется</font>|
# | <font size=3>{'a': 1, 'b': 2}</font> | <font size=3>с = 3</font> | <font size=3>f(D, с=с)</font> | <font size=3>{'a': 1, 'b': 2}</font> |<font size=3>Ключа `'c'` нет в словаре `D`,<br>и поэтому `D` не изменяется</font>|
# | <font size=3>{'a': 1, 'b': 2}</font> | <font size=3>a = 1<br>b = 1<br>с = 3</font> | <font size=3>f(D, a=a, b=b с=с)</font> | <font size=3>{'b': 1}</font> |<font size=3>&nbsp;</font>|
# | <font size=3>{'a': 3, 'b': 2}</font> | <font size=3>D1 = {'a': 1, 'b': 5, 'c':3}</font> | <font size=3>Распаковка словаря<br>при вызове функции</font> | <font size=3>{'a': 2}</font> | &nbsp; |
#
# ####  Что делать?
#
# 1. Реализовать функцию `subtract_from_dict()`.
#
# 2. Передать именованные аргументы в функцию с помощью распаковки словаря `D2`.
#
# 3. Ничего не нужно считывать с клавиатуры.
#
# 4. Ничего не нужно печатать.
#
# ### Критерии
# | <font size=3>баллы</font> | <font size=3>критерий</font> |
# | :---: | :---: |
# | <font size=3>0</font> | <font size=3>решение содержит ошибку</font> |
# | <font size=3>3</font> | <font size=3>задача полностью решена</font> |

# %%
D = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}
D2 = {'a': 5, 'b': 4, 'c': 3, 'd': 2, 'e': 1}

# %% [markdown]
# # <font color=blue>Задача 2. Модификация JSON</font>
#
# Пока не будет введена строка `"STOP"`, считывайте с клавиатуры имена JSON-файлов, содержащие словари, и добавляйте (или модифицируйте) их элементы (нужно модифицировать сами файлы, а не загружать словари из файлов и менять полученные объекты Python)
#
# 1. Если JSON-файл существует, добавьте в словарь новый элемент или измените значение существующего элемента. Сохраните модифицированный объект обратнов JSON.
#
# 2. Если файл не существует - создайте его и запишите в файл словарь с поданным на вход элементом.
#
# Чтобы проверить, существует ли файл, нужно импортировать модуль `os` и вызвать функцию `os.path.isfile()`. Например
#
# ```python
# import os
# file_name = 'some_file.txt'
# if os.path.isfile(file_name):
#     with open(file_name) as f:
#         pass
# else:
#     pass  # Если файл не существует, то его не возможно открыть на чтение
# ```
#
# Ключами словарей являются строки, а значениями - целые числа.
#
# В подаваемых на вход строках через пробел записаны 3 слова:
#
# 1) имя JSON-файла,
#
# 2) ключ элемента словаря,
#
# 3) значение элемента словаря.
#
# Программа не должна ничего печатать, только создавать и модифицировать JSON-файлы.
#
#
# | <font size=3>Словари в файлах<br>до выполнения программы</font> | <font size=3>Входные данные</font> | <font size=3>Словари в файлах<br>после выполнения программы</font> |
# | :---: | :---: | :---: |
# | <font size=3><font color=green>ex2_d1.json</font>: {'a': 1, 'b': 2}<br><font color=green>ex2_d2.json</font>: {'c': 3}</font> | <font size=3>ex2_d1.json a 3<br>ex2_d1.json d 4<br>ex2_d2.json d 5<br>ex2_d3.json a -1<br>STOP</font> | <font size=3><font color=green>ex2_d1.json</font>: {'a': 3, 'b': 2, 'd': 4}<br><font color=green>ex2_d2.json</font>: {'c': 3, 'd': 5}<br><font color=green>ex2_d3.json</font>: {'a': -1}</font> |
#
# ### Критерии
# | <font size=3>баллы</font> | <font size=3>критерий</font> |
# | :---: | :---: |
# | <font size=3>0</font> | <font size=3>решение содержит ошибку</font> |
# | <font size=3>4</font> | <font size=3>задача полностью решена</font> |

# %% [markdown]
# # <font color=blue>Задача 3. Файловый прыг-скок</font>
#
# Переместитесь в корневой каталог Вашей файловой системы следующим образом.
#
# 1. Из директории с данным ноутбуком (test12.ipynb) переместитесь ближе к корневому каталогу.
#
# 2. Если новая текущая директория не является корневой, вернитесь в каталог с программой (в каталог с файлом test12.ipynb) одним шагом (одним вызовом функции `os.chdir`).
#
# 3. Повторите пункты 1 и 2, но теперь поднимитесь на одну папку выше.
#
# 4. При перемещении с помощью функции `os.chdir()` используйте **только относительные пути**.
#
# 5. При первом выполнении пункта 1 надо поднять на одну директорию.
#
# Распечатайте абсолютные пути ко всем текущим директориям процесса в том порядке, в котором они сменялись в процессе работы программы. **Реализуйте программу так, чтобы она работала вне зависимости от того, в каком она находится.**
#
# ### Пример
#
# Пусть ноутбук находится по пути <font color=green>/home/user/a/b/c/test12.ipynb</font>  или <font color=green>С:\Users\User\a\test12.ipynb</font>. В таком случае смены текущей директории процесса будет происходить в следующем порядке.
#
# | <font size=3>Текущая директория (пример выходных данных)</font> | <font size=3>Комментарий</font> |
# | :---: | :---: |
# | <font size=3>/home/user/a/b/c<br>/home/user/a/b<br>/home/user/a/b/c<br>/home/user/a<br>/home/user/a/b/c<br>/home/user<br>/home/user/a/b/c<br>/home<br>/home/user/a/b/c<br>/</font> | <font size=3><font color=green>/home/user/a/b/c</font> -<br>начальная директория,<br>содержащая test12.ipynb</font> |
# | <font size=3>`С:\Users\User\a`<br>`С:\Users\User`<br>`С:\Users\User\a`<br>`С:\Users`<br>`С:\Users\User\a`<br>`С:\`</font> | <font size=3><font color=green>`С:\Users\User\a`</font> -<br>начальная директория,<br>содержащая test12.ipynb</font> |
#
#
# ### Критерии
# | <font size=3>баллы</font> | <font size=3>критерий</font> |
# | :---: | :---: |
# | <font size=3>0</font> | <font size=3>решение содержит ошибку</font> |
# | <font size=3>2</font> | <font size=3>используются переходы по абсолютным путям<br>и (или) переходы выполняются не за 1 шаг</font> |
# | <font size=3>4</font> | <font size=3>задача полностью решена</font> |

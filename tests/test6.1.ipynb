# %% [markdown]
# # <font color=blue>test6.1</font>
# <font color=red>Время выполнения: 35 мин</font>
#
# # <font color=blue>Задача 1. Транспонирование списков </font>
#
# Ниже приведены 5 списков целых чисел $A$, $B$, $C$, $D$, $E$ по 3 элемента каждый.
#
# 1. Составьте из них с помощью `zip()` 3 кортежа $a$, $b$, $c$: по 5 элементов в каждом. В списке $a$ должны быть первые элементы исходных 5-ти списков, в списке $b$ - вторые элементы исходных 5-ти списков и т.д..
#
# 2. Выполните совместную итерацию по спискам $a$, $b$, $c$ с помощью `zip()`. Распечатайте в цикле суммы элементов $a$, $b$, $c$ с одинаковыми индексами.
#
# Программа ничего не получает на вход.
#
# | <font size=3>Исходные списки </font> | <font size=3>Выходные данные</font>    |
# | :--- | :--- |
# | <font size=3>`A = [1, 2, 3]`<br>`B = [4, 5, 6]`<br>`C = [7, 8, 9]`<br>`D = [10, 11, 12]`<br>`E = [13, 14, 15]`</font> | <font size=3>6<br>15<br>24<br>33<br>42</font> |
#
# ### Критерии
#
# За каждый решенный пункт присуждается по одному баллу, при условии, что в решениях используется `zip()`.

# %%
A = [1, 2, 3]
B = [4, 5, 6]
C = [7, 8, 9]
D = [10, 11, 12]
E = [13, 14, 15]

# %% [markdown]
# # <font color=blue>Задача 2. Цикл по `zip()` и  `enumerate()`</font>
#
# Даны 2 списка $A$ и $B$.
#
# <font color=green>**1. Распечатайте списки так, чтобы элементы, находящиеся на одной позиции, выводились вместе. Используйте `zip()`**</font>
#
# ## Пример:
#
# ```python
# A = [1, 2, 3, 4]
# B = [5, 6, 7, 8]
# C = [9, 10, 11, 12]
# ```
# #### Вывод:
#
# ```
# 1 5 9
# 2 6 10
# 3 7 11
# 4 8 12
# ```
#
# <font color=green>**2. Распечатайте списки так, чтобы сначала выводились элементы списков, а затем их индекс. Используйте `zip()` и  `enumerate()`.**</font>
#
# ## Пример:
#
# ```python
# A = ['a', 'b', 'c', 'd']
# B = ['e', 'f', 'g', 'h']
# С = ['i', 'j', 'k', 'l']
# ```
# #### Вывод:
#
# ```
# a e i 0
# b f j 1
# c g k 2
# d h l 3
# ```
#
# ### Критерии
# За каждый пункт присуждается по баллу, при условии, что в обоих используется `zip()`, а в последнем `enumerate()`.
#
# **<font color=red>Соблюдайте формат вывода</font>**

# %%
A = [1, 2, 3, 4]
B = [5, 6, 7, 8]
C = [9, 10, 11, 12]

# %%
A = ['a', 'b', 'c', 'd']
B = ['e', 'f', 'g', 'h']
С = ['i', 'j', 'k', 'l']

# %% [markdown]
# # <font color=blue>Задача 3. Математические операции над множествами</font>
#
# Выведите символы, которые присутствуют ровно в одной из четырех поданных на вход строк. В выходных данных символы должны быть в одном экземпляре.
#
#  На выходе должна быть строка, составленная из найденных символов.
#
# | <font size=3>Входные данные</font>      | <font size=3>Выходные данные</font>    |
# | :---: | :---: |
# | <font size=3>abc<br>cde<br>efa<br>bce</font> | <font size=3>df</font> |
# | <font size=3>abcdfghl<br>abcefijm<br>abdegikn<br>acdehjko</font> | <font size=3>lmno</font> |
#
# ### Критерии
# | <font size=3>баллы</font> | <font size=3>критерий</font> |
# | :---: | :---: |
# | <font size=3>0</font> | <font size=3>решение содержит ошибку</font> |
# | <font size=3>2</font> | <font size=3>решение верно</font> |
#
# **<font color=red>Соблюдайте формат вывода</font>**

# %% [markdown]
# # <font color=blue> Задача 4. Файлы</font>
#
# С клавиатуры вводятся имена файлов и слова, которые нужно в них записать.  Каждое из слов, добавляемых в файл, пишется в файле в отдельной строке. В конце каждого из файлов должен стоять символ "новая строка" `"\n"`.
#
# ### Требования
#
# 1. В процессе работы не должно быть одновременно 2-х открытых файлов.
#
# 2. Реализуйте открытие и закрытие файлов с помощью контекстных менеджеров.
#
# В каждой строке входных данных есть два слова, разделенные пробелом: имя файла и слово, помещаемое в этот файл. Ввод завершается строкой `"STOP"`. В следующей таблице приведен пример входных данных и содержимого файлов после завершения работы программы.
#
# **Гарантируется, что файлы с именами, которые вводятся с клавиатуры, до начала работы программы не существуют.**
#
# | <font size=3>Входные данные</font> | <font size=3>test6.1_ex4_f1.txt</font> | <font size=3>test6.1_ex4_f2.txt</font> | <font size=3>test6.1_ex4_f3.txt</font> |
# | :---: | :---: | :---: | :---: |
# | <font size=3>test6.1_ex4_f1.txt python<br>test6.1_ex4_f2.txt 4ever<br>test6.1_ex4_f1.txt keep<br>test6.1_ex4_f2.txt calm<br>test6.1_ex4_f3.txt and<br>test6.1_ex4_f1.txt code<br>STOP</font> | <font size=3>python<br>keep<br>code</font> | <font size=3>4ever<br>calm</font> | <font size=3>and</font> |
#
#
# ### Критерии
# | <font size=3>баллы</font> | <font size=3>критерий</font> |
# | :---: | :---: |
# | <font size=3>0</font> | <font size=3>решение содержит ошибку</font> |
# | <font size=3>3</font> | <font size=3>решение верно</font> |

# %% [markdown]
# # <font color=blue> Задача 5. Странный способ печатать список</font>
#
# С клавиатуры вводится список целых чисел `L` в виде строки, в которой числа разделены пробелами. Распечатайте список `L` согласно следующим правилам.
#
# 1. Индекс $i$ выводимого элемента списка `L` равен значению последнего распечатанного элемента, кроме случаев, в которых этот индекс указывает на уже распечатанный элемент или за пределы списка.
#
# 2. Если индекс $i$ указывает на уже распечатанный элемент или за пределы списка, то выводится тот из нераспечатанных элементов, у которого наименьший индекс.
#
# 3. Печать начинается с нулевого элемента и производится, пока все элементы не будут выведены на экран.
#
# **Отрицательные индексы тоже используются.**
#
# На выходе должна получится строка, в которой элементы списка разделены пробелами. В следующей клетке демонстрируется, как можно использовать встроенную функцию `print()` для этой цели.
#
# | <font size=3>Входные данные</font>  | <font size=3>Выходные данные</font> |
# | :---: | :---: |
# | <font size=3>1 2 3 4 5 0</font> | <font size=3>1 2 3 4 5 0</font> |
# | <font size=3>5 3 10 2 0 4</font> | <font size=3>5 4 0 3 2 10</font> |
# | <font size=3>15 3 10 2 0 4</font> | <font size=3>15 3 2 10 0 4</font> |
# | <font size=3>-1 2 -3 2 0 -5</font> | <font size=3>-1 -5 2 -3 2 0</font> |
#
# ### Подсказка
#
# Может пригодиться метод [`list.index()`](https://docs.python.org/3/tutorial/datastructures.html#list.index).
#
# ### Критерии
# | <font size=3>баллы</font> | <font size=3>критерий</font> |
# | :---: | :---: |
# | <font size=3>0</font> | <font size=3>решение содержит ошибку</font> |
# | <font size=3>4</font> | <font size=3>решение верно</font> |
#
# **<font color=red>Соблюдайте формат вывода</font>**

# %%
print('a', end=' ')
print('b', end=' ')
print('c')

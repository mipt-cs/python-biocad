# %% [markdown]
# # Упражнение 1. Прислуга
#
# Вам предлагается оптимизировать систему классов, описывающию состав прислуги уважаемого британского дома. Имеются классы `Butler` (дворецкий), `HouseKeeper` (домохозяйка), `Valet` (камердинер), `Maid` (горничная), `Footman` (лакей), `Cook` (кухарка). Используя наследование и встроенную функцию `super()`, уменьшите количество повторяющегося кода. Можно вводить новые классы. Обязательное требование - сохранить функциал исходных классов. Не стремитесь к совершеству: не нужно искать лучшее решение, даже если оно есть.

# %%
class Butler:
    position = 'Butler'
    
    def __init__(
            self,
            name,
            age,
            salary=90,
            experience=95,
            pride=100,
            walking_speed=4,
            responsibilities=(),
            subordinates=()
    ):
        self.name = name
        self.age = age
        self.salary = salary
        self.experience = experience
        self.pride = pride
        self.walking_speed = walking_speed
        self.responsibilities = list(responsibilities)
        self.subordinates = list(subordinates)
        
        self.speaker_prefix = '{} {}: '.format(self.position, self.name)
        
    def open_house_door(self, solemnity=50):
        if solemnity > 80:
            print('{}greeting1'.format(self.speaker_prefix))
        elif solemnity > 50:
            print('{}greeting2'.format(self.speaker_prefix))
        elif solemnity > 20:
            print('{}greeting3'.format(self.speaker_prefix))
        else:
            print('{}greeting4'.format(self.speaker_prefix))
            
    def call_employee_to_order(self, employee_name):
        print(
            "{}{}, I don't remember permitting you to fool around!".format(
                self.speaker_prefix, employee_name
            )
        )
        
    def add_new_subordinate(self, subordinate):
        self.subordinates.append(subordinate)
        
    def consult_on_business_matters(self):
        print("{}How can I help you, sir?".format(self.speaker_prefix))
    
    def organise_team_work(self):
        pass
    
    def go(self, hurry=False):
        print("Going at speed {}".format(self.walking_speed))
        
    def rest(self):
        print("Resting")
        
    def eat(self):
        print("Eating")
        
    def get_list_responsibilities(self):
        return self.responsibilities
        
        
class HouseKeeper:
    position = 'House Keeper'
    
    def __init__(
            self,
            name,
            age,
            salary=60,
            experience=95,
            pride=85,
            walking_speed=5,
            responsibilities=(),
            subordinates=()
    ):
        self.name = name
        self.age = age
        self.salary = salary
        self.experience = experience
        self.pride = pride
        self.walking_speed = walking_speed
        self.responsibilities = list(responsibilities)
        self.subordinates = list(subordinates)
        
        self.speaker_prefix = '{} {}: '.format(self.position, self.name)
            
    def call_employee_to_order(self, employee_name):
        print(
            "{}{}, I don't remember permitting you to fool around!".format(
                self.speaker_prefix, employee_name
            )
        )
        
    def add_new_subordinate(self, subordinate):
        self.subordinates.append(subordinate)
        
    def consult_on_business_matters(self):
        print("{}How can I help you, sir?".format(self.speaker_prefix))
    
    def organise_team_work(self):
        print("Organising team work")
    
    def organise_cleaning(self):
        print("Organising cleaning")
    
    def go(self, hurry=False):
        print("Going at speed {}".format(self.walking_speed * 1.2))
        
    def rest(self):
        print("Resting")
        
    def eat(self):
        print("Eating")
        
    def get_list_responsibilities(self):
        return self.responsibilities
    
    
class Valet:
    position = 'Valet'
    
    def __init__(
            self,
            name,
            age,
            salary=65,
            experience=90,
            pride=85,
            walking_speed=5,
            responsibilities=(),
    ):
        self.name = name
        self.age = age
        self.salary = salary
        self.experience = experience
        self.pride = pride
        self.walking_speed = walking_speed
        self.responsibilities = list(responsibilities)
        
        self.speaker_prefix = '{} {}: '.format(self.position, self.name)
    
    def go(self, hurry=False):
        print("Going at speed {}".format(self.walking_speed * 1.2))
        
    def rest(self):
        print("Resting")
        
    def eat(self):
        print("Eating")
        
    def get_list_responsibilities(self):
        return self.responsibilities
    
    def clean_masters_clothes(self):
        print("Cleaning masters clothes")
        
    def carry_masters_luggage(self):
        print("Carrying masters luggage")
        
    def help_get_dressed(self):
        print("Helping getting dressed")
        
        
class Valet:
    position = 'Valet'
    
    def __init__(
            self,
            name,
            age,
            salary=65,
            experience=90,
            pride=85,
            walking_speed=5,
            responsibilities=(),
    ):
        self.name = name
        self.age = age
        self.salary = salary
        self.experience = experience
        self.pride = pride
        self.walking_speed = walking_speed
        self.responsibilities = list(responsibilities)
        
        self.speaker_prefix = '{} {}: '.format(self.position, self.name)
    
    def go(self, hurry=False):
        print("Going at speed {}".format(self.walking_speed * 1.2))
        
    def rest(self):
        print("Resting")
        
    def eat(self):
        print("Eating")
        
    def get_list_responsibilities(self):
        return self.responsibilities
    
    def clean_masters_clothes(self):
        print("Cleaning masters clothes")
        
    def carry_masters_luggage(self):
        print("Carrying masters luggage")
        
    def help_get_dressed(self):
        print("Helping getting dressed")

        
        
class Maid:
    position = 'Maid'
    
    def __init__(
            self,
            name,
            age,
            salary=30,
            experience=45,
            pride=30,
            walking_speed=7,
            responsibilities=(),
    ):
        self.name = name
        self.age = age
        self.salary = salary
        self.experience = experience
        self.pride = pride
        self.walking_speed = walking_speed
        self.responsibilities = list(responsibilities)
        
        self.speaker_prefix = '{} {}: '.format(self.position, self.name)
    
    def go(self, hurry=False):
        print("Going at speed {}".format(self.walking_speed * 2))
        
    def rest(self):
        print("Resting")
        
    def eat(self):
        print("Eating")
        
    def get_list_responsibilities(self):
        return self.responsibilities
    
    def clean_mistress_clothes(self):
        print("Cleaning masters clothes")
        
    def help_get_dressed(self):
        print("Helping getting dressed")
        
    def do_housework(self):
        print("Doing housework")
        
    def help_take_bath(self):
        print("Helping take a bath")
        
    def gossip(self):
        print("Gossiping")
        
    
class FootMan:
    position = 'FootMan'
    
    def __init__(
            self,
            name,
            age,
            salary=40,
            experience=40,
            pride=50,
            walking_speed=8,
            responsibilities=(),
    ):
        self.name = name
        self.age = age
        self.salary = salary
        self.experience = experience
        self.pride = pride
        self.walking_speed = walking_speed
        self.responsibilities = list(responsibilities)
        
        self.speaker_prefix = '{} {}: '.format(self.position, self.name)
    
    def go(self, hurry=False):
        print("Going at speed {}".format(self.walking_speed * 2))
        
    def rest(self):
        print("Resting")
        
    def eat(self):
        print("Eating")
        
    def get_list_responsibilities(self):
        return self.responsibilities
        
    def double_as_valet(self):
        print("Substituting valet")
        
    def do_housework(self):
        print("Doing housework")
        
    def serve_at_table(self):
        print("Serving at the table")
        
    def open_a_door(self):
        print("Openning a door")
        
        
class Cook:
    def __init__(
            self,
            name,
            age,
            salary=50,
            experience=80,
            pride=50,
            walking_speed=5,
            responsibilities=(),
    ):
        self.name = name
        self.age = age
        self.salary = salary
        self.experience = experience
        self.pride = pride
        self.walking_speed = walking_speed
        self.responsibilities = list(responsibilities)
        
        self.speaker_prefix = '{} {}: '.format(self.position, self.name)
    
    def go(self, hurry=False):
        print("Going at speed {}".format(self.walking_speed * 1.5))
        
    def rest(self):
        print("Resting")
        
    def eat(self):
        print("Eating")
        
    def get_list_responsibilities(self):
        return self.responsibilities
        
    def clean_kitchen(self):
        print("Cleaning the kitchen")
        
    def cook(self):
        print("Cooking")

# %% [markdown]
# # Упражнение 2. Вызов методов родительских классов
#
# Из классах `A`, `B` и `C` есть методы `f()` и `g()`, причем все методы `f()` вызывают метод `g()`.
# 1. Допишите в методе `C.method()` вызовы методов `A.f()`, `B.f()`, `C.f()`.
#
# 2. Модифицируйте методы `A.f()` и `B.f()` так, чтобы при вызове `X.f()`, `X.f()` вызывал `X.g()` (`X` -- это `A` или `B`).

# %%
class A:
    def f(self):
        print("Method `f()` in class `A`")
        self.g()
        
    def g(self):
        print("Method `g()` in class `A`")
        

class B(A):
    def f(self):
        print("Method `f()` in class `B`")
        self.g()
        
    def g(self):
        print("Method `g()` in class `B`")
        

class C(B):
    def f(self):
        print("Method `f()` in class `C`")
        self.g()
        
    def g(self):
        print("Method `g()` in class `C`")
        
    def method(self):
        pass

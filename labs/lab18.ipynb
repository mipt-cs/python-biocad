# %% [markdown]
# # <font color=blue>Упражнение 1. Шахматный король</font>
#
# Шахматный король ходит по горизонтали, вертикали и диагонали на 1 клетку. Даны две различные клетки шахматной доски, определите, может ли король попасть с первой клетки на вторую одним ходом. Программа получает на вход четыре числа от 1 до 8 каждое, задающие номер столбца и номер строки сначала для первой клетки, потом для второй клетки. Программа должна вывести YES, если из первой клетки ходом короля можно попасть во вторую или NO в противном случае.
#
# Для простоты можно не рассматривать случай, когда данные клетки совпадают.

# %% [markdown]
# # <font color=blue>Упражнение 2. Срезы</font>
#
# Составьте из элементов списка <font color=red face="Courier" size=3>A</font> список <font color=red face="Courier" size=3>B</font>, в котором будут элементы с 0-го по 9-й, с 20-го по 29-й, с 40-го по 49-й и т.д.. Длина списка <font color=red face="Courier" size=3>A</font> равна 1000.

# %%
import random
A = [random.randint(-1000, 1000) for _ in range(1000)]

# %% [markdown]
# # <font color=blue>Упражнение 3. Совместная сортировка списков</font>
#
# Отсортируйте поданные на вход списки целых чисел <font color=red face="Courier" size=3>A</font> и <font color=red face="Courier" size=3>B</font> по элементам списка <font color=red face="Courier" size=3>A</font>. Распечатайте результат.

# %% [markdown]
# # <font color=blue>Упражнение 4. Удаление элементов из словаря</font>
#
# Удалите из словаря все элементы, чьи значения являются строками. Проверку того, к какому типу относится объект, можно с помощью встроенной функции [`isinstance()`](https://docs.python.org/3/library/functions.html#isinstance).
#
# ```python
# print(isinstance(1, int))
# ```

# %% [markdown]
# # <font color=blue>Упражнение 5. Применение анонимных функций и функция `sorted()`</font>
#
# 1. Получите список <font color=blue face="courier" size=3>A</font>, в котором элементы <font color=blue face="courier" size=3>L[i]</font> списка натуральных чисел <font color=blue face="courier" size=3>L</font> будут расположены по возрастанию их зеркальные числа. Под числом, зеркальным к числу <font color=blue face="courier" size=3>L[i]</font>, понимается число, составленное из цифр <font color=blue face="courier" size=3>L[i]</font>, записанных в обратном порядке **без ведущих нулей**. Используйте встроенную функцию <font color=blue face="courier" size=3>sorted()</font> и ее именованный аргумент <font color=blue face="courier" size=3>key</font>. **Запрещается использовать результат, полученный при решении 2-го пункта.**
#
# 2. Упорядочите элементы списка <font color=blue face="courier" size=3>L</font> **по убыванию** их зеркальных вариантов. Используйте метод списков <font color=blue face="courier" size=3>list.sort()</font>. **Запрещается использовать результат, полученный при решении 1-го пункта.**
#
# ### Указания
#
# 1. Используйте анонимные функции
#
# ### Подсказки
#
# 1. Можно преобразовать натуральное число в строку.
#
# 2. Чтобы избавиться от ведущих нулей в строке, подойдут функции [`str.rstrip()`](https://docs.python.org/3/library/stdtypes.html#str.rstrip) и [`str.lstrip()`](https://docs.python.org/3/library/stdtypes.html#str.lstrip).
#
# 3. Число можно развернуть с помощью целочисленного деления на 10 и взятия остатка при делении на 10 так, как мы это сделали в лабораторной работе на рекурсию (lab7).
#
# ### Входные и выходные данные
#
# На вход подаются натуральные числа, разделенные пробелами, которые надо поместить в список <font color=blue face="courier" size=3>L</font>.
#
# На выходе должны быть распечатаны **через пробел** списки <font color=blue face="courier" size=3>A</font> и <font color=blue face="courier" size=3>L</font>.
#
# |<font size=3>Входные данные</font>| <font size=3>Выходные данные</font> |
# | :---: | :---: |
# | <font size=3>1 2 3 4</font> | <font size=3>1 2 3 4<br>4 3 2 1</font> |
# | <font size=3>11 12 13 14</font> | <font size=3>11 12 13 14<br>14 13 12 11</font> |
# | <font size=3>14 23 32 41</font> | <font size=3>41 32 23 14<br>14 23 32 41</font> |
# | <font size=3>4 30 200 1000</font> | <font size=3>1000 200 30 4<br>4 30 200 1000</font> |
#
# ### Критерии
# 1. Решения засчитываются, если используется именованный аргумент <font color=blue face="courier" size=3>key</font>.
#
# 2. Если в решении нет анонимных функций, то за каждый пункт начисляется 1 балл.
#
# 3. Если в решении правильно используются анонимные функции, то 1 решенный пункт начисляются 2 балла, а за 2 решенных пункта начисляются 3 балла.

# %% [markdown]
# # <font color=blue>Упражнение 6. Множества</font>
#
# На вход подаются $N$ списков целых чисел, распечатайте все числа, входящие ровно в 2 из приведенных списков. На вход сначала подается число $N$, а затем $N$ списков: каждый в отдельной строке.

# %% [markdown]
# # <font color=blue>Упражнение 7. Подсчет слов</font>
#
# Посчитайте число уникальных слов в тексте из файла <font color=green face="Courier" size=3>lab18_ex7_inp.txt</font> и запишите их в файл <font color=green face="Courier" size=3>dir/lab18_ex7_out.txt</font> в порядке убывания встречаемости вместе с числом экземпляров этого слова в тексте. Разбиение на слова производите по пробелам. Кроме файла <font color=green face="Courier" size=3>lab18_ex7_out.txt</font> в <font color=green face="Courier" size=3>dir</font> не должно остаться других файлов и папок.
#
# ```bash
# wget https://raw.githubusercontent.com/mipt-cs/python-biocad/master/files/lab18/lab18_ex7_inp.txt
# ```

# %% [markdown]
# # <font color=blue>Упражнение 8. `zip()`</font>
#
# Транспонируйте матрицу (список списков) $A$ с помощью `zip()` и получите $A^T$ в виде списка кортежей $B$. Распечатайте транспонированную  матрицу $A$ итерацией по `zip`-объекту.  Транспонируйте матрицу $B$ с помощью `zip()` и получите $B^T$ в виде списка списков $C$. Запишите матрицы $B$ и $C$ в файлы <font color=green face="Courier" size=3>ex8_B.txt</font> и <font color=green face="Courier" size=3>ex8_C.txt</font> (числа в строках должны разделяться табуляциями).

# %%
import random
N = random.randint(5, 15)
M = random.randint(5, 15)
A = [[j * N + i for i in range(M)] for j in range(N)]

# %% [markdown]
# # <font color=blue>Упражнение 9. Количество четных цифр</font>
#
# Посчитать количество вхождений четных чисел в строку.
#
# ### Формат входных данных
# На вход подается не пустая строка `S` длины < 256 символов. Строка состоит и цифр, букв английского алфавита и пробелов.
#
# ### Формат выходных данных
# Неотрицательное целое число C - количество подстрок в строке, являющихся четными числами. **Числами не являются подстроки с ведущими нулями, число символов в которых превышает 1. Подстрока `"0"` является четным числом.**
#
# | <font size=3>Входные данные</font> | <font size=3>Выходные данные</font> | <font size=3>Четные числа</font> |
# | :---: | :---: | :---: |
# | <font size=3>asdcsa2331 00</font> | <font size=3>3</font> | <font size=3>2 0 0</font> |
# | <font size=3>2436</font> | <font size=3>7</font> | <font size=3>2 4 6 24 36 436 2436</font> |
#
# ### Подсказка
#
# Задача решается в 1 проход.

# %% [markdown]
# # <font color=blue>Упражнение 10. Зайчик</font>
#
# В нашем зоопарке появился заяц. Его поместили в клетку, и чтобы ему не было скучно, директор зоопарка распорядился поставить в его клетке лесенку. Теперь наш зайчик может прыгать по лесенке вверх, перепрыгивая через ступеньки. Лестница имеет определенное количество ступенек $N$. Заяц может одним прыжком преодолеть не более $K$ ступенек. Для разнообразия зайчик пытается каждый раз найти новый путь к вершине лестницы. Директору любопытно, сколько различных способов есть у зайца добраться до вершины лестницы при заданных значениях $K$ и $N$. Помогите директору написать программу, которая поможет вычислить это количество. Например, если $K=3$ и $N=4$, то существуют следующие маршруты: $1+1+1+1$, $1+1+2$, $1+2+1$, $2+1+1$, $2+2$, $1+3$, $3+1$. Т.е. при данных значениях у зайца всего 7 различных маршрутов добраться до вершины лестницы.
#
# Решите задачу с помощью цикла и с помощью рекурсии. Оцените число операций сложения в решении с помощью цикла и в решении с помощью рекурсии.
#
# На вход через пробел подаются два числа: $N$ и $K$, а на выходе должно быть число способов, которыми зайчик может подняться по лестнице.
#
# | <font size=3>Входные данные</font> | <font size=3>Выходные данные</font> |
# | :---: | :--- |
# | <font size=3>1 1</font> | <font size=3>1</font> |
# | <font size=3>4 1</font> | <font size=3>1</font> |
# | <font size=3>4 3</font> | <font size=3>7</font> |
# | <font size=3>5 3</font> | <font size=3>13</font> |
# | <font size=3>20 6</font> | <font size=3>463968</font> |
# | <font size=3>1000 10</font> | <font size=3></font> |
#
# ### Примечание
# Последний случай невозможно посчитать с помощью рекурсии.

# %% [markdown]
# # <font color=blue>Упражнение 11. Множества 2</font>
#
# На вход подаются $N$ списков целых чисел, распечатайте все числа, входящие ровно в $K$ из приведенных списков. На вход сначала подаются числа $N$ и $K$, а затем $N$ списков: каждый в отдельной строке.

# %% [markdown]
# # <font color=blue>Упражнение 12. Отрезки</font>
#
# Вдоль координатной прямой размещены $N$ отрезков; каждый отрезок задатся координатами начала и конца $x_{min}$ и $x_{max}$. Нужно найти какую-либо точку, принадлежащую всем отрезкам, или сказать, что таких точек нет.

# %% [markdown]
# # <font color=blue>Упражнение 13. Сумма кубов</font>
#
# Известно, что любое натуральное число можно представить в виде суммы не более чем четырех квадратов натуральных чисел. Вася решил придумать аналогичное утверждение для кубов - он хочет узнать, сколько кубов достаточно для представления любого числа. Его первая рабочая гипотеза - восемь.
#
# Выяснилось, что почти все числа, которые Вася смог придумать, представляются в виде суммы не более чем восьми кубов. Однако число 239, например, не допускает такого представления. Теперь Вася хочет найти какие-либо другие такие числа, а также, возможно, какую-либо закономерность в представлениях всех остальных чисел, чтобы выдвинуть гипотезу относительно вида всех чисел, которые не представляются в виде суммы восьми кубов.
#
# Помогите Васе написать программу, которая проверяла бы, возможно ли представить данное натуральное число в виде суммы не более чем восьми кубов натуральных чисел, и если это возможно, то находила бы какое-либо такое представление.

# %% [markdown]
# # <font color=blue>Упражнение 14. Сумма двух чисел</font>
#
# Заданы три числа: a, b, c. Необходимо выяснить, можно ли так переставить цифры в числах a и b, чтобы в сумме получилось c.

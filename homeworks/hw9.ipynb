# %% [markdown]
# ## <font color=blue>Литература</font>
#
# 1. Алгоритмы и программы. Решение олимпиадных задач. - И.Н. Порублев, А.Б. Ставровский. Выложена в канале **#edu_materials**

# %% [markdown]
# # Упражнение 1. Третий максимум
#
# Напишите программу, опредеделяющую третье по величине число в последовательности. Сначала подается количество чисел в последовательности $N$ (**любое неотрицательное число**), а затем $N$ чисел (каждое в отдельной строке). Если $N < 3$ выведите `None`.
#
# | <font size=3>Входные данные</font> | <font size=3>Выходные данные</font>    |
# | :--- | :--- |
# | <font size=3>4<br>1<br>2<br>-1.5<br>0</font> | <font size=3>0</font> |
# | <font size=3>2<br>1<br>2</font> | <font size=3>None</font> |

# %% [markdown]
# # Упражнение 2. Ближайшая точка
#
# На плоскости задан круг с центром в начале координат и набор точек. Его радиус, количество точек и их координаты вводятся с клавиатуры. Найдите точку вне круга, ближайшую к нему. Разобрана в <font color=blue>[1]</font>.

# %% [markdown]
# # Упражнение 3. Максимальное произведение 3-х чисел
#
# Из последовательности целых чисел выбрать 3 числа, произведение которых максимально
#
# *Вход.* В первой строке текста - количество чисел $N$, $3 \leq N \leq 10^8$, в следующих $N$ строках - целые числа.
#
# *Выход.* Три числа в произвольном порядке.
#
# Есть указания к решению в <font color=blue>[1]</font>.

# %% [markdown]
# # Упражнение 4. Чтение и вычисление многочлена
# Многочлен с переменной $x$ записывают, соблюдая такие правила:
#
# - многочлен состоит из слагаемых со знаками `+` или `-` между ними; количество слагаемых от 1 до 100;
#
# - каждое слагаемое представляет собой или произведение натурального коэффициента на степень $x$ (например `5*x^2`), или только степень $x$ (например, `x^3`), или только коэффициент (например `7`);
#
# - степень записывается в виде: буква `x` (строчная латинская), знак `^`, показатель степени (натуральное число);
#
# - в выражении нет пробелов; после него в конце строки записан 1 пробел.
#
# Вычислить значение многочлена при заданном действительном значении $x$.
#
# *Вход.* В первой строке подается значение $x$, во второй многослен, записанный по указанным правилам.
#
# Разобрана в <font color=blue>[1]</font>.

# %% [markdown]
# # Упражнение 5. Пары чисел
#
# Заданы $2 N$ положительных целых чисел, которые можно разбить на пары так, что суммы чисел во всех парах одинаковы. Определить, можно ли их разбить на пары так, что произведения чисел во всех парах одинаковы.
#
# *Вход.* Первая строка содержит количество пар чисел $N$ ($1 \leq N \leq 2 \cdot 10^9$). В следующих $2N$ строках записаны натуральные числа $a_1,~a_2,~...,a_2N$
#
# *Выход.* 1, если искомое разбиение существует, иначе 0.
#
# Есть указания к решению в <font color=blue>[1]</font>.

# %% [markdown]
# # Упражнение 6. Число, встречающееся менее 3-х раз
#
# В последовательности записаны целые числа. Число X встречается один или два раза, остальные числа — по три раза. Найти число X. Для простоты считаем, что числа неотрицательные.
#
# [Тут](https://habr.com/post/243819/) есть разбор.

# %% [markdown]
# # Упражнение 7. Инопланетная армия
#
# Солдаты инопланетной армии перед походом строятся в колонну, поворачиваясь к командиру правым или левым боком. По команде они начинают готовиться к движению. Если двое соседних солдат стоят лицом друг к другу, оба за одну секунду разворачиваются на 180o. Развороты разных пар солдат происходят одновременно. Армия сможет начать движение, если в колонне не будет солдат, стоящих лицом друг к другу. По начальному расположению солдат нужно определить, отправится ли когда-нибудь армия в поход, и если да, то через сколько секунд и какое общее количество разворотов выполнят солдаты.
#
# *Вход.* Последовательность символов `<` и `>` длиной до $9 \cdot 10^4$ в одной строке текста; `<` означает, что солдат стоит лицом налево, `>` - направо.
#
# *Выход.* Время и общее количество разворотов (через пробел), если армия сможет отправиться в поход, иначе слово `infinite`.
#
# Разобрана в <font color=blue>[1]</font>.
